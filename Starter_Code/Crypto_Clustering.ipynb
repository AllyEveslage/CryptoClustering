# %%
# Import required libraries and dependencies
import pandas as pd
import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='43709712-9106-4ed1-a07f-a2664bdfcc30'>
#   <div id="e3728ea0-8d03-445f-ab7c-8802e78a2cc8" data-root-id="43709712-9106-4ed1-a07f-a2664bdfcc30" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Load the data into a Pandas DataFrame
df_market_data = pd.read_csv(
    "Resources/crypto_market_data.csv",
    index_col="coin_id")

# Display sample data
df_market_data.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                              1.08388                     7.60278
# ethereum                             0.22392                    10.38134
# tether                              -0.21173                     0.04935
# ripple                              -0.37819                    -0.60926
# bitcoin-cash                         2.90585                    17.09717
# binancecoin                          2.10423                    12.85511
# chainlink                           -0.23935                    20.69459
# cardano                              0.00322                    13.99302
# litecoin                            -0.06341                     6.60221
# bitcoin-cash-sv                      0.92530                     3.29641
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %%
# Generate summary statistics
df_market_data.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# ...

# %%
# Plot your data to see what's in your DataFrame
df_market_data.hvplot.line(
    width=800,
    height=400,
    rot=90
)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [coin_id]   (value)

# %% [markdown]
# ---

# %% [markdown]
# ### Prepare the Data

# %%
#Making a list to see Column names
list_1 = []
for el in df_market_data.columns:
    list_1.append(el)

#Print to double check
print(list_1)
# Out:
# ['price_change_percentage_24h', 'price_change_percentage_7d', 'price_change_percentage_14d', 'price_change_percentage_30d', 'price_change_percentage_60d', 'price_change_percentage_200d', 'price_change_percentage_1y']

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
crypto_scaled = StandardScaler().fit_transform(df_market_data[list_1])

# Show result
print(crypto_scaled)
# Out:
# [[ 5.08529366e-01  4.93193071e-01  7.72200433e-01  2.35459633e-01
#   -6.74950963e-02 -3.55953481e-01 -2.51636882e-01]
#  [ 1.85445894e-01  9.34445040e-01  5.58692121e-01 -5.43409317e-02
#   -2.73482725e-01 -1.15759474e-01 -1.99352110e-01]
#  [ 2.17739616e-02 -7.06336853e-01 -2.16804207e-02 -6.10301536e-02
#    8.00452481e-03 -5.50246924e-01 -2.82060506e-01]
#  [-4.07643829e-02 -8.10928066e-01  2.49457974e-01 -5.03879651e-02
#   -3.73164019e-01 -4.58258816e-01 -2.95546142e-01]
#  [ 1.19303608e+00  2.00095907e+00  1.76061001e+00  5.45842065e-01
#   -2.91202870e-01 -4.99847761e-01 -2.70316950e-01]
#  [ 8.91870708e-01  1.32729453e+00  8.00214184e-01 -5.71478992e-02
#    7.78653106e-01 -1.88231917e-01 -2.25532605e-01]
#  [ 1.13972400e-02  2.57225091e+00  1.10164693e+00 -4.90495415e-01
#   -9.31954023e-01  3.87758986e-01 -1.82843995e-02]
#  [ 1.02529802e-01  1.50800146e+00  6.48885061e-01  3.28959245e-01
#   -4.86348899e-01  6.50796233e-02 -1.55428416e-01]
# ...

# %%
# Create a DataFrame with the scaled data
scaled_df = pd.DataFrame(crypto_scaled, columns = list_1)

# Copy the crypto names from the original DataFrame
scaled_df = scaled_df.set_index(pd.read_csv("Resources/crypto_market_data.csv")["coin_id"])

# Set the coin_id column as index
#Did above ^^

# Display the scaled DataFrame
scaled_df.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Original Scaled DataFrame.

# %%
# Create a list with the number of k-values from 1 to 11

k_values = list(range(1, 12))  # range is exclusive at the end, so use 12

# %%
# Create an empty list to store the inertia values
inertia = []

# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using `df_market_data_scaled`
# 3. Append the model.inertia_ to the inertia list
for i in k_values:
    model_i = KMeans(n_clusters=i, random_state=1)
    model_i.fit(scaled_df)
    inertia.append(model_i.inertia_)
# Out:
# C:\Users\12182\anaconda3\New\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\12182\anaconda3\New\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\12182\anaconda3\New\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
# Create a dictionary with the data to plot the Elbow curve
inertia_dict = {"k_values": k_values, "inertia": inertia}

# Create a DataFrame with the data to plot the Elbow curve
inertia_df = pd.DataFrame(inertia_dict)
inertia_df
# Out:
#     k_values     inertia
# 0          1  287.000000
# 1          2  212.123342
# 2          3  165.136752
# 3          4   79.022435
# 4          5   66.413051
# 5          6   61.634088
# 6          7   46.074467
# 7          8   43.392694
# 8          9   32.913223
# 9         10   30.469111
# 10        11   26.480101

# %%
# Plot a line chart with all the inertia values computed with
# the different values of k to visually identify the optimal value for k.
elbow_1 = inertia_df.hvplot.line(
    x="k_values",
    y="inertia",
    title="Elbow Curve",
    xticks=k_values)

elbow_1
# Out:
# :Curve   [k_values]   (inertia)

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the best value for `k`?
#
# **Answer:** The best value for k is 4

# %% [markdown]
# ---

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Original Scaled DataFrame

# %%
# Initialize the K-Means model using the best value for k
crypto_clusters = KMeans (n_clusters=4, random_state=1)

# %%
# Fit the K-Means model using the scaled DataFrame
crypto_clusters.fit(scaled_df)
# Out:
# C:\Users\12182\anaconda3\New\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4, random_state=1)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled DataFrame
k_4 = crypto_clusters.predict(scaled_df)

# Print the resulting array of cluster values.
k_4
# Out:
# array([2, 2, 0, 0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 2, 0, 2, 0, 0, 2, 0, 0, 2,
#        0, 0, 0, 0, 0, 0, 2, 0, 0, 0, 3, 2, 0, 0, 1, 0, 0, 0, 0])

# %%
# Create a copy of the scaled DataFrame
clusters_predicted = scaled_df.copy()

# %%
# Add a new column to the copy of the scaled DataFrame with the predicted clusters
clusters_predicted['predicted_cluster'] = k_4

# Display the copy of the scaled DataFrame
clusters_predicted.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %%
# Create a scatter plot using hvPlot by setting
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`.
# Color the graph points with the labels found using K-Means and
# add the crypto name in the `hover_cols` parameter to identify
# the cryptocurrency represented by each data point.
cluster_1 = clusters_predicted.hvplot.scatter(
    x='price_change_percentage_24h',
    y='price_change_percentage_7d',
    by='predicted_cluster',
    hover_cols='coin_id')

cluster_1
# Out:
# :NdOverlay   [predicted_cluster]
#    :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)

# %% [markdown]
# ---

# %% [markdown]
# ### Optimize Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=3`.
pca= PCA(n_components=3)

# %%
# Use the PCA model with `fit_transform` to reduce the original scaled DataFrame
# down to three principal components.
pca_1 = pca.fit_transform(scaled_df)

# View the scaled PCA data
pca_1
# Out:
# array([[-0.60066733,  0.84276006,  0.46159457],
#        [-0.45826071,  0.45846566,  0.95287678],
#        [-0.43306981, -0.16812638, -0.64175193],
#        [-0.47183495, -0.22266008, -0.47905316],
#        [-1.15779997,  2.04120919,  1.85971527],
#        [-0.51653377,  1.38837748,  0.80407131],
#        [-0.45071134,  0.51769912,  2.84614316],
#        [-0.34559977,  0.72943939,  1.47801284],
#        [-0.64946792,  0.43216514,  0.60030286],
#        [-0.75901394, -0.20119979, -0.21765292],
#        [-0.24819846, -1.37625159, -1.46202571],
#        [-0.43840762, -0.17533654, -0.6633884 ],
#        [-0.69342533, -0.47381462, -0.52759693],
#        [ 0.06049915,  2.90940385,  1.49857131],
#        [-0.39335243, -0.10819197, -0.01275608],
#        [-0.79617564, -0.49440875,  1.08281169],
#        [ 0.06407452, -1.26982514, -1.09882928],
#        [-0.48901506, -0.73271912, -0.06254323],
#        [-0.3062723 ,  0.70341515,  1.71422359],
#        [-0.51352775, -0.14280239, -0.65656583],
# ...

# %%
# Retrieve the explained variance to determine how much information
# can be attributed to each principal component.
print(pca.explained_variance_ratio_)
# Out:
# [0.3719856  0.34700813 0.17603793]

# %%
print(sum(pca.explained_variance_ratio_))
# Out:
# 0.895031657030984

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the total explained variance of the three principal components?
#
# **Answer:** The total explained variance is 0.895 - pretty good!

# %%
# Create a new DataFrame with the PCA data.
pca_df = pd.DataFrame(pca_1, columns = ["PC1", "PC2", "PC3"])

# Copy the crypto names from the original scaled DataFrame
pca_df = pca_df.set_index(pd.read_csv("Resources/crypto_market_data.csv")['coin_id'])

# Set the coin_id column as index
#Did above ^^^

# Display the scaled PCA DataFrame
pca_df.head()
# Out:
#                    PC1       PC2       PC3
# coin_id
# bitcoin      -0.600667  0.842760  0.461595
# ethereum     -0.458261  0.458466  0.952877
# tether       -0.433070 -0.168126 -0.641752
# ripple       -0.471835 -0.222660 -0.479053
# bitcoin-cash -1.157800  2.041209  1.859715

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Scaled PCA DataFrame

# %%
# Create a list with the number of k-values from 1 to 11
k_values = list(range(1, 12))

# %%
# Create an empty list to store the inertia values
pca_inertia = []

# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using `df_market_data_pca`
# 3. Append the model.inertia_ to the inertia list
for i in k_values:
    model_i = KMeans(n_clusters = i, random_state = 1)
    model_i.fit(pca_df)
    pca_inertia.append(model_i.inertia_)
# Out:
# C:\Users\12182\anaconda3\New\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\12182\anaconda3\New\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\12182\anaconda3\New\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
# Create a dictionary with the data to plot the Elbow curve
pca_dict = {'k_values': k_values, "inertia" : pca_inertia}
# Create a DataFrame with the data to plot the Elbow curve
pca_inertia_df = pd.DataFrame(pca_dict)

# %%
# Plot a line chart with all the inertia values computed with
# the different values of k to visually identify the optimal value for k.
elbow_2 = pca_inertia_df.hvplot.line(
    x='k_values',
    y='inertia',
    xticks=k_values)

elbow_2
# Out:
# :Curve   [k_values]   (inertia)

# %% [markdown]
# #### Answer the following questions:
#
# * **Question:** What is the best value for `k` when using the PCA data?
#
#   * **Answer:** The best value for k is 4
#
#
# * **Question:** Does it differ from the best k value found using the original data?
#
#   * **Answer:** The original data in comparison shows no differences - the inertia values look identical to the original data

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Scaled PCA DataFrame

# %%
# Initialize the K-Means model using the best value for k
pcafourcluster = KMeans(n_clusters=4, random_state=1)

# %%
# Fit the K-Means model using the PCA data
pcafourcluster.fit(pca_df)
# Out:
# C:\Users\12182\anaconda3\New\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4, random_state=1)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled PCA DataFrame
pcapred= pcafourcluster.predict(pca_df)

# Print the resulting array of cluster values.
print(pcapred)
# Out:
# [2 2 0 0 2 2 2 2 2 0 0 0 0 2 0 2 0 0 2 0 0 2 0 0 0 0 0 0 2 0 0 0 3 2 0 0 1
#  0 0 0 0]

# %%
# Create a copy of the scaled PCA DataFrame
pca_pred_df = pca_df.copy()

# Add a new column to the copy of the PCA DataFrame with the predicted clusters
pca_pred_df["pred"] = pcapred

# Display the copy of the scaled PCA DataFrame
pca_pred_df.head()
# Out:
#                    PC1       PC2       PC3  pred
# coin_id
# bitcoin      -0.600667  0.842760  0.461595     2
# ethereum     -0.458261  0.458466  0.952877     2
# tether       -0.433070 -0.168126 -0.641752     0
# ripple       -0.471835 -0.222660 -0.479053     0
# bitcoin-cash -1.157800  2.041209  1.859715     2

# %%
# Create a scatter plot using hvPlot by setting
# `x="PC1"` and `y="PC2"`.
# Color the graph points with the labels found using K-Means and
# add the crypto name in the `hover_cols` parameter to identify
# the cryptocurrency represented by each data point.
cluster_2 = pca_pred_df.hvplot.scatter(
    x='PC1',
    y='PC2',
    by='pred',
    hover_cols='coin_id')

cluster_2
# Out:
# :NdOverlay   [pred]
#    :Scatter   [PC1]   (PC2,coin_id)

# %% [markdown]
# ### Visualize and Compare the Results
#
# In this section, you will visually analyze the cluster analysis results by contrasting the outcome with and without using the optimization techniques.

# %%
# Composite plot to contrast the Elbow curves
elbow_1*elbow_2
# Out:
# :Overlay
#    .Curve.I  :Curve   [k_values]   (inertia)
#    .Curve.II :Curve   [k_values]   (inertia)

# %%
# Composite plot to contrast the clusters
cluster_1*cluster_2
# Out:
# :Overlay
#    .NdOverlay.I  :NdOverlay   [predicted_cluster]
#       :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)
#    .NdOverlay.II :NdOverlay   [pred]
#       :Scatter   [PC1]   (PC2,coin_id)

# %% [markdown]
# #### Answer the following question:
#
#   * **Question:** After visually analyzing the cluster analysis results, what is the impact of using fewer features to cluster the data using K-Means?
#
#   * **Answer:** In this view, there is overall less clutter visually. In this format, the graphs are much more appealing and easier to comprehend when explained. The tighter clusters make the information more digestable. This was especially helpful during the ETL portion.
